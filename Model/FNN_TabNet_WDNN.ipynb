# %% [markdown]
# # About this notebook
#
# This notebook presents three different Deep Learning models for training Universal Bank dataset. These are the models which are taken:
#
# - Feedforward Neural Network with k-Fold validation
# - TabNet model with k-Fold validation
# - Wide & Deep neural network architecture
#
# Amongst this, TabNet model is selected which gives 0.985 validation accuracy.

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading the Dataset

# %%
train = pd.read_csv('UniversalBank.csv')

# %% [markdown]
# # Dataset Description
#
# #### Observations
#
# 1. Minimum value of Experience is -3 which is not possible.
# 2. ZIP Code is not a numeric data. It is to be considered as nominal data. Out of 5000 records, there are only 467 unique ZIP codes. Thus this represents that the dataset is restricted to a particular region.
# 3. Education has 3 unique values {1: Bachelor, 2: Masters, 3: Advanced Degree}. So this is again not a numeric data. It is ordinal data.
# 4. Personal Loan (Target Variable) is either 0 or 1. {0: Loan not approved, 1: Loan approved}. So this is binary data,
# 5. Securities Account is binary data representing {0: doesn't have security account, 1: has security account}
# 6. CD Account is binary data representing {0: doesn't have CD Account, 1: has CD Account}
# 7. Online is binary data representing {0: doesn't use online banking, 1: uses online banking}
# 8. Credit Card is binary data representing {0: doesn't have credit card, 1: has credit card}
# 9. ID is the unique column representing IDs of records.
#
# Rest are numeric data

# %%
train.describe()
# Out:
#                 ID          Age   Experience       Income       ZIP Code  \
# count  5000.000000  5000.000000  5000.000000  5000.000000    5000.000000
# mean   2500.500000    45.338400    20.104600   624.719926  526463.109800
# std    1443.520003    11.463166    11.467954   389.813620  230920.155438
# min       1.000000    23.000000    -3.000000    67.744000  110001.000000
# 25%    1250.750000    35.000000    10.000000   330.252000  360001.000000
# 50%    2500.500000    45.000000    20.000000   541.952000  518001.000000
# 75%    3750.250000    55.000000    30.000000   829.864000  756001.000000
# max    5000.000000    67.000000    43.000000  1896.832000  854105.000000
#
#             Family        CCAvg    Education     Mortgage  Personal Loan  \
# count  5000.000000  5000.000000  5000.000000  5000.000000    5000.000000
# mean      2.396400    16.410459     1.881000   478.431838       0.096000
# std       1.147663    14.799176     0.839869   861.312476       0.294621
# min       1.000000     0.000000     1.000000     0.000000       0.000000
# 25%       1.000000     5.927600     1.000000     0.000000       0.000000
# 50%       2.000000    12.702000     2.000000     0.000000       0.000000
# 75%       3.000000    21.170000     3.000000   855.268000       0.000000
# max       4.000000    84.680000     3.000000  5377.180000       1.000000
#
#        Securities Account  CD Account       Online   CreditCard
# count         5000.000000  5000.00000  5000.000000  5000.000000
# mean             0.104400     0.06040     0.596800     0.294000
# std              0.305809     0.23825     0.490589     0.455637
# min              0.000000     0.00000     0.000000     0.000000
# 25%              0.000000     0.00000     0.000000     0.000000
# 50%              0.000000     0.00000     1.000000     0.000000
# 75%              0.000000     0.00000     1.000000     1.000000
# max              1.000000     1.00000     1.000000     1.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  5000 non-null   int64
#  1   Age                 5000 non-null   int64
#  2   Experience          5000 non-null   int64
#  3   Income              5000 non-null   float64
#  4   ZIP Code            5000 non-null   int64
#  5   Family              5000 non-null   int64
#  6   CCAvg               5000 non-null   float64
#  7   Education           5000 non-null   int64
#  8   Mortgage            5000 non-null   float64
#  9   Personal Loan       5000 non-null   int64
#  10  Securities Account  5000 non-null   int64
#  11  CD Account          5000 non-null   int64
#  12  Online              5000 non-null   int64
#  13  CreditCard          5000 non-null   int64
# dtypes: float64(3), int64(11)
# memory usage: 547.0 KB

# %% [markdown]
# # Checking for negative values if any
#
# It can be seen that Experience field has 52 negative values. But this field should always be zero or positive.

# %%
(train < 0).sum()
# Out:
# ID                     0
# Age                    0
# Experience            52
# Income                 0
# ZIP Code               0
# Family                 0
# CCAvg                  0
# Education              0
# Mortgage               0
# Personal Loan          0
# Securities Account     0
# CD Account             0
# Online                 0
# CreditCard             0
# dtype: int64

# %% [markdown]
# # Type Casting
#
# 1. Numeric to Boolean
# 2. Numeric to String

# %%
train['ZIP Code'].nunique() # Out of 5000 records, there are 467 unique values
# Out:
# 169

# %%
train['CD Account'] = train['CD Account'].astype(bool)
train['Online'] = train['Online'].astype(bool)
train['CreditCard'] = train['CreditCard'].astype(bool)
train['Personal Loan'] = train['Personal Loan'].astype(bool)
train['ZIP Code'] = train['ZIP Code'].astype(str)
train['Education'] = train['Education'].astype(str)
train['Securities Account'] = train['Securities Account'].astype(bool)

# %% [markdown]
#
#       Mortgage  Personal Loan  Securities Account  CD Account  Online  \
# 89       0.000          False               False       False   False
# 226      0.000          False               False       False   False
# 315      0.000          False               False       False    True
# 451    753.652          False               False       False    True
# 524      0.000          False               False       False    True
# 536   1490.368          False               False       False    True
# 540   2658.952          False               False       False    True
# 576      0.000          False               False       False   False
# 583      0.000          False               False       False    True
# 597      0.000          False                True       False   False
# 649      0.000          False               False       False    True
# 670   2023.852          False               False       False    True
# 686      0.000          False               False       False    True
# 793      0.000          False               False       False    True
# 889      0.000          False               False       False    True
# 909   2582.740          False               False       False   False
# 1173     0.000          False               False       False   False
# 1428   762.120          False               False       False    True
# 1522  2167.808          False               False       False   False
# 1905  2040.788          False               False       False    True
# 2102     0.000          False               False       False    True
# 2430     0.000          False               False       False    True
# 2466     0.000          False               False       False    True
# 2545     0.000          False               False       False    True
# 2618  1227.860          False               False       False    True
# 2717     0.000          False               False       False    True
# 2848     0.000          False               False       False   False
# 2876  2015.384          False               False       False   False
# 2962     0.000          False               False       False   False
# 2980     0.000          False               False       False   False
# 3076     0.000          False               False       False   False
# 3130     0.000          False                True       False   False
# 3157   711.312          False               False       False    True
# 3279     0.000          False               False       False   False
# 3284     0.000          False               False       False   False
# 3292     0.000          False                True       False   False
# 3394     0.000          False               False       False    True
# 3425   762.120          False               False       False    True
# 3626     0.000          False               False       False   False
# 3796     0.000          False                True       False   False
# 3824     0.000          False                True       False   False
# 3887     0.000          False                True       False    True
# 3946     0.000          False               False       False    True
# 4015     0.000          False               False       False   False
# 4088     0.000          False               False       False   False
# 4116     0.000          False               False       False    True
# 4285     0.000          False               False       False    True
# 4411     0.000          False               False       False    True
# 4481     0.000          False               False       False    True
# 4514     0.000          False               False       False    True
# 4582     0.000          False               False       False    True
# 4957     0.000          False               False       False   False
#
#       CreditCard
# 89          True
# 226        False
# 315        False
# 451        False
# 524        False
# 536        False
# 540        False
# 576         True
# 583        False
# 597         True
# 649        False
# 670        False
# 686        False
# 793        False
# 889         True
# 909         True
# 1173       False
# 1428       False
# 1522        True
# 1905       False
# 2102        True
# 2430       False
# 2466       False
# 2545       False
# 2618       False
# 2717        True
# 2848       False
# 2876       False
# 2962       False
# 2980       False
# 3076        True
# 3130        True
# 3157       False
# 3279       False
# 3284        True
# 3292       False
# 3394       False
# 3425       False
# 3626       False
# 3796       False
# 3824        True
# 3887       False
# 3946       False
# 4015        True
# 4088       False
# 4116       False
# 4285       False
# 4411        True
# 4481       False
# 4514       False
# 4582       False
# 4957        True

# %% [markdown]
# # Cheking the minimum difference between age and experience
#
# So at age 23, people have no experience. So after 23, they can have n year experience.

# %%
n = 0
while True:
    m = (train['Age'] - train['Experience'] <= n).sum()
    if m > 0:
        break
    n += 1
print(n)
# Out:
# 24

# %%
train.loc[train['Experience'] < 0, 'Experience'] = train.loc[train['Experience'] < 0, 'Age'] - 23

# %%
train.describe() # checkong the minimum and maximum Experience value
# Out:
#                 ID          Age   Experience       Income       Family  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean   2500.500000    45.338400    20.135400   624.719926     2.396400
# std    1443.520003    11.463166    11.414672   389.813620     1.147663
# min       1.000000    23.000000     0.000000    67.744000     1.000000
# 25%    1250.750000    35.000000    10.000000   330.252000     1.000000
# 50%    2500.500000    45.000000    20.000000   541.952000     2.000000
# 75%    3750.250000    55.000000    30.000000   829.864000     3.000000
# max    5000.000000    67.000000    43.000000  1896.832000     4.000000
#
#              CCAvg     Mortgage
# count  5000.000000  5000.000000
# mean     16.410459   478.431838
# std      14.799176   861.312476
# min       0.000000     0.000000
# 25%       5.927600     0.000000
# 50%      12.702000     0.000000
# 75%      21.170000   855.268000
# max      84.680000  5377.180000

# %% [markdown]
# # Data-preprocessing
#
# This code performs data preprocessing tasks, particularly encoding categorical variables and frequency encoding one of the features.
#
# #### Frequency Encoding for 'ZIP Code':
#
# - Calculates the frequency of each unique value in the 'ZIP Code' column by dividing the count of each value by the total number of samples in the DataFrame.
# - Maps these frequencies to the corresponding 'ZIP Code' values in the DataFrame, effectively encoding the 'ZIP Code' column with its frequency values.
# - Saves the frequency encoding dictionary (zip_code_freq) using the joblib.dump() function to a file named 'zip_code_freq_encoder.pkl'.
#
# #### Label Encoding for Categorical Columns:
#
# - Specifies a list of columns (columns_to_encode) that need to be label encoded: 'Education', 'Personal Loan', 'CD Account', 'Online', 'CreditCard', and 'Securities Account'.
# - Iterates over each column in columns_to_encode and applies label encoding using LabelEncoder() from scikit-learn.
# - Saves the trained label encoders for each column in a dictionary (label_encoders) where the column name is the key and the corresponding label encoder is the value.
# - Updates the DataFrame train by replacing the original categorical values with their encoded counterparts.
#
# #### Saving Label Encoders:
#
# - Saves the dictionary of label encoders (label_encoders) to a file named 'label_encoders.pkl' using the joblib.dump() function.

# %%
import os
from sklearn.preprocessing import LabelEncoder
import joblib
import pandas as pd
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define the save directory in Google Drive
save_dir = '/content/drive/MyDrive/Bank Loan Approval Prediction/'

# Ensure the directory exists in Google Drive
os.makedirs(save_dir, exist_ok=True)

# Check if the directory exists and is accessible
if os.path.exists(save_dir):
    print(f"Directory exists: {save_dir}")
else:
    print(f"Directory does not exist: {save_dir}")

# Frequency encoding for 'ZIP Code'
zip_code_freq = train['ZIP Code'].value_counts() / len(train)
train['ZIP Code'] = train['ZIP Code'].map(zip_code_freq)

 # Save frequency encoding
zip_code_path = os.path.join(save_dir, 'zip_code_freq_encoder.pkl')
joblib.dump(zip_code_freq, zip_code_path)
print(f"Frequency encoding saved at: {zip_code_path}")

# Columns to encode using LabelEncoder
columns_to_encode = ['Education', 'Personal Loan', 'CD Account', 'Online', 'CreditCard', 'Securities Account']

# Initialize a single label encoder dictionary to store the label encoders
label_encoders = {}

# Encoding the columns using LabelEncoder
for col in columns_to_encode:
    le = LabelEncoder()
    train[col] = le.fit_transform(train[col])
    label_encoders[col] = le

# Save label encoders
label_encoders_path = os.path.join(save_dir, 'label_encoders.pkl')
joblib.dump(label_encoders, label_encoders_path)
print(f"Label encoders saved at: {label_encoders_path}")

# Displaying info of the updated DataFrame
print("\nUpdated DataFrame Info:")
print(train.info())
# Out:
# Mounted at /content/drive
# Directory exists: /content/drive/MyDrive/Bank Loan Approval Prediction/
# Frequency encoding saved at: /content/drive/MyDrive/Bank Loan Approval Prediction/zip_code_freq_encoder.pkl
# Label encoders saved at: /content/drive/MyDrive/Bank Loan Approval Prediction/label_encoders.pkl
#
# Updated DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  5000 non-null   int64
#  1   Age                 5000 non-null   int64
#  2   Experience          5000 non-null   int64
#  3   Income              5000 non-null   float64
#  4   ZIP Code            5000 non-null   float64
#  5   Family              5000 non-null   int64
#  6   CCAvg               5000 non-null   float64
#  7   Education           5000 non-null   int64
#  8   Mortgage            5000 non-null   float64
#  9   Personal Loan       5000 non-null   int64
#  10  Securities Account  5000 non-null   int64
#  11  CD Account          5000 non-null   int64
#  12  Online              5000 non-null   int64
#  13  CreditCard          5000 non-null   int64
# dtypes: float64(4), int64(10)
# memory usage: 547.0 KB
# None

# %% [markdown]
# # Correlation Matrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


correlation_matrix = train.corr()

# Plotting the correlation matrix using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Data Visualization
#
# #### Histogram of Age
# - This plot shows the distribution of ages in the dataset.
# - The histogram is stacked by the 'Personal Loan' variable, allowing us to see the distribution of ages for those who got and those who did not get personal loans.
# - It helps visualize if there are any differences in age distribution between those who got personal loans and those who did not.
#
# #### Boxplot of Income
# - This plot displays the distribution of income for each category of 'Personal Loan'.
# - The boxplot provides information about the median, quartiles, and potential outliers in income for each group.
# - It helps us to identify if there are significant differences in income between those who got personal loans and those who did not.
#
# #### Barplot of Education
# - This plot shows the count of individuals in each category of education, separated by the 'Personal Loan' variable.
# - It helps visualize the distribution of education levels among those who got personal loans and those who did not.
# - Differences in the proportions of education levels between the two groups can be observed.
#
# #### Violin Plot of CCAvg
# - This plot displays the distribution of average credit card spending (CCAvg) for each category of 'Personal Loan'.
# - It combines the features of a box plot and a kernel density plot, showing both summary statistics and the probability density of the data at different values.
# - It helps compare the distribution of CCAvg between individuals who got personal loans and those who did not.
#
# #### Boxen Plot of Mortgage
# - This plot shows the distribution of mortgage amounts for each category of 'Personal Loan'.
# - Similar to a box plot, it displays information about the median, quartiles, and potential outliers in mortgage amounts for each group.
# - It helps identify any differences in mortgage amounts between individuals who got personal loans and those who did not.
#
# #### Swarm Plot of Experience
# - This plot displays the distribution of work experience (in years) for each category of 'Personal Loan'.
# - It shows individual data points along the categorical axis, providing a clearer picture of the distribution compared to a traditional scatter plot.
# - It helps visualize if there are any patterns or differences in work experience between individuals who got personal loans and those who did not.
#
# These plots collectively provide insights into how different variables relate to the likelihood of individuals accepting personal loans.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the figure and axes
fig, axs = plt.subplots(3, 2, figsize=(14, 18))

# Plot 1: Histogram of Age
sns.histplot(data=train, x='Age', hue='Personal Loan', multiple='stack', ax=axs[0, 0])
axs[0, 0].set_title('Distribution of Age')

# Plot 2: Boxplot of Income
sns.boxplot(data=train, y='Income', x='Personal Loan', ax=axs[0, 1])
axs[0, 1].set_title('Boxplot of Income')

# Plot 3: Barplot of Education
sns.countplot(data=train, x='Education', hue='Personal Loan', ax=axs[1, 0])
axs[1, 0].set_title('Distribution of Education')

# Plot 4: Violin Plot of CCAvg
sns.violinplot(data=train, x='Personal Loan', y='CCAvg', ax=axs[1, 1])
axs[1, 1].set_title('CCAvg Distribution by Personal Loan')

# Plot 5: Boxen Plot of Mortgage
sns.boxenplot(data=train, x='Personal Loan', y='Mortgage', ax=axs[2, 0])
axs[2, 0].set_title('Mortgage Distribution by Personal Loan')

# Plot 6: Swarm Plot of Experience
sns.swarmplot(data=train, x='Personal Loan', y='Experience', ax=axs[2, 1])
axs[2, 1].set_title('Experience Distribution by Personal Loan')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %%
X = train.drop(['ID', 'Personal Loan'], axis=1)  # Features
y = train['Personal Loan']  # Target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# converting to numpy arrays

X = X.to_numpy()
y = y.to_numpy()

# %%
# import necessary modules
# !pip install pytorch-tabnet

from pytorch_tabnet.tab_model import TabNetClassifier

import os
import torch

from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
# Out:
# Collecting pytorch-tabnet
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (1.26.4)
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (1.5.2)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (1.13.1)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (2.5.1+cu121)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (4.66.6)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>0.21->pytorch-tabnet) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>0.21->pytorch-tabnet) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.3->pytorch-tabnet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3->pytorch-tabnet) (3.0.2)
# Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: pytorch-tabnet
# Successfully installed pytorch-tabnet-4.1.0

# %% [markdown]
# # Feedforward Neural Network
#
# A Feedforward Neural Network (FNN) is a type of artificial neural network where connections between the nodes do not form a cycle. It is the simplest form of neural networks where the information moves in only one direction—forward—from the input nodes, through the hidden nodes (if any), and to the output nodes. There are no loops or cycles in the network.
#
# #### Key Components:
# - Input Layer: This layer receives the input data.
# - Hidden Layers: Intermediate layers where computations are performed. These layers apply transformations to the input data and pass it to the next layer.
# - Output Layer: Produces the final output of the network. For binary classification, a single neuron with a sigmoid activation function is typically used.
# - Activation Functions: Non-linear functions applied to each layer's output to introduce non-linearity into the network, allowing it to learn complex patterns.
#
# Here we implement a feedforward neural network for binary classification using TensorFlow and Keras. It uses K-Fold Cross-Validation to evaluate the model's performance, ensuring that the results are robust and generalize well to unseen data. Each fold involves training a new model and applying early stopping to prevent overfitting, with the best epoch's weights restored for evaluation.
#
# #### Layers:
# - The first dense layer has 64 neurons and uses the ReLU activation function.
# - The second dense layer has 32 neurons and also uses the ReLU activation function.
# - The output layer has 1 neuron and uses the sigmoid activation function to output a probability for binary classification.
#
# #### Compilation:
# - The loss function is binary_crossentropy, suitable for binary classification.
# - The optimizer is adam, an adaptive learning rate optimizer.
# - The metric is accuracy.
#
# #### K-Fold Cross-Validation:
# - The dataset is split into 5 parts (folds).
#
# <br><br>
#
# <table style="text-align: center; width: 80%; font-size: 16px; border-collapse: collapse;">
#     <caption>Accuracies over all folds</caption>
#     <tr>
#         <th style="border: 1px solid black;"> </th>
#         <th style="border: 1px solid black;">Fold 1</th>
#         <th style="border: 1px solid black;">Fold 2</th>
#         <th style="border: 1px solid black;">Fold 3</th>
#         <th style="border: 1px solid black;">Fold 4</th>
#         <th style="border: 1px solid black;">Fold 5</th>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black;">Best Epoch</th>
#         <td style="border: 1px solid black;">47</td>
#         <td style="border: 1px solid black;">45</td>
#         <td style="border: 1px solid black;">25</td>
#         <td style="border: 1px solid black;">47</td>
#         <td style="border: 1px solid black;">45</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black;">Final Validation Loss</th>
#         <td style="border: 1px solid black;">0.1204</td>
#         <td style="border: 1px solid black;">0.0833</td>
#         <td style="border: 1px solid black;">0.1053</td>
#         <td style="border: 1px solid black;">0.1113</td>
#         <td style="border: 1px solid black;">0.0882</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black;">Final Validation Accuracy</th>
#         <td style="border: 1px solid black;">0.9549</td>
#         <td style="border: 1px solid black;">0.9620</td>
#         <td style="border: 1px solid black;">0.9660</td>
#         <td style="border: 1px solid black;">0.9679</td>
#         <td style="border: 1px solid black;">0.9710</td>
#     </tr>
# </table>
#
#
#
# <br>
# Overall Average Validation Loss: 0.10173177272081375 <br>
# Overall Average Validation Accuracy: 0.9644000053405761

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# Feedforward Neural Network model architecture
def create_model():
    model = tf.keras.Sequential([
      tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
      tf.keras.layers.Dense(32, activation='relu'),
      tf.keras.layers.Dense(1, activation='sigmoid')  # binary classification
    ])
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# K-Fold parameters
n_splits = 5
random_state = 42

# KFold object
kf = KFold(n_splits=n_splits, random_state=random_state, shuffle=True)

# Lists to store results
CV_loss_history = []
CV_accuracy_history = []

# Lists to store the actual and predicted values for calculating overall confusion matrix
y_true_all = []
y_pred_all = []

for fold_index, (train_index, test_index) in enumerate(kf.split(X)):

    # Splitting data into training and validation sets
    X_train, X_valid = X[train_index], X[test_index]
    y_train, y_valid = y[train_index], y[test_index]

    # Creating a new FNN model for each fold
    model = create_model()

    # Early stopping callback to track best epoch for validation accuracy
    early_stopping = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True)

    # Training the model with early stopping
    history = model.fit(X_train, y_train, epochs=50, validation_data=(X_valid, y_valid), callbacks=[early_stopping])

    # Getting final validation loss and accuracy
    val_loss = history.history['val_loss'][-1]
    val_acc = history.history['val_accuracy'][-1]

    # Making predictions on validation set (probabilities)
    y_pred_prob = model.predict(X_valid)
    y_pred_class = (y_pred_prob > 0.5).astype(int)  # Converting probabilities to binary classes

    # Adding the true and predicted values for confusion matrix
    y_true_all.extend(y_valid)
    y_pred_all.extend(y_pred_class)

    # Printing results, including best epoch from EarlyStopping callback
    print(f"\nFold: {fold_index+1}")
    print(f"Best Epoch (Validation Accuracy): {early_stopping.best_epoch}")
    print(f"Final Validation Loss: {val_loss}")
    print(f"Final Validation Accuracy: {val_acc}")

    # Storing results
    CV_loss_history.append(val_loss)
    CV_accuracy_history.append(val_acc)

# After all folds, calculate the overall confusion matrix
cm = confusion_matrix(y_true_all, y_pred_all)
accuracy = accuracy_score(y_true_all, y_pred_all)
precision = precision_score(y_true_all, y_pred_all)
recall = recall_score(y_true_all, y_pred_all)
f1 = f1_score(y_true_all, y_pred_all)

# Printing the overall confusion matrix and classification metrics
print(f"\nOverall Confusion Matrix:\n{cm}")
print(f"Overall Accuracy: {accuracy}")
print(f"Overall Precision: {precision}")
print(f"Overall Recall: {recall}")
print(f"Overall F1 Score: {f1}")

# Printing K-Fold evaluation results (average loss, accuracy)
print(f"\nOverall Average Validation Loss: {np.mean(CV_loss_history)}")
print(f"Overall Average Validation Accuracy: {np.mean(CV_accuracy_history)}")
# Out:
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.7771 - loss: 9.1793 - val_accuracy: 0.8850 - val_loss: 0.3279
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8737 - loss: 0.5464 - val_accuracy: 0.7880 - val_loss: 0.9334
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8670 - loss: 0.9578 - val_accuracy: 0.8920 - val_loss: 0.3968
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8905 - loss: 0.6055 - val_accuracy: 0.8670 - val_loss: 0.4488
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8820 - loss: 0.5384 - val_accuracy: 0.9220 - val_loss: 0.2136
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8877 - loss: 0.5588 - val_accuracy: 0.7760 - val_loss: 0.7984
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8644 - loss: 0.8842 - val_accuracy: 0.8990 - val_loss: 0.6227
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8925 - loss: 0.6220 - val_accuracy: 0.8950 - val_loss: 1.0318
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
# Epoch 40/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9138 - loss: 0.5593 - val_accuracy: 0.9180 - val_loss: 0.2551
# Epoch 41/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9188 - loss: 0.2612 - val_accuracy: 0.9110 - val_loss: 0.2160
# Epoch 42/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9138 - loss: 0.3389 - val_accuracy: 0.9090 - val_loss: 0.2699
# Epoch 43/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9165 - loss: 0.2804 - val_accuracy: 0.9220 - val_loss: 0.2104
# Epoch 44/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9125 - loss: 0.3135 - val_accuracy: 0.9340 - val_loss: 0.2041
# Epoch 45/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9037 - loss: 0.3819 - val_accuracy: 0.9380 - val_loss: 0.6438
# Epoch 46/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9142 - loss: 0.4941 - val_accuracy: 0.9220 - val_loss: 0.2649
# Epoch 47/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9215 - loss: 0.3500 - val_accuracy: 0.9360 - val_loss: 0.1697
# Epoch 48/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9166 - loss: 0.2771 - val_accuracy: 0.7930 - val_loss: 0.9798
# Epoch 49/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8945 - loss: 0.4989 - val_accuracy: 0.9240 - val_loss: 0.5723
# Epoch 50/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9100 - loss: 0.4508 - val_accuracy: 0.9290 - val_loss: 0.2053
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Fold: 5
# Best Epoch (Validation Accuracy): 37
# Final Validation Loss: 0.20531871914863586
# Final Validation Accuracy: 0.9290000200271606
#
# Overall Confusion Matrix:
# [[4425   95]
#  [ 185  295]]
# Overall Accuracy: 0.944
# Overall Precision: 0.7564102564102564
# Overall Recall: 0.6145833333333334
# Overall F1 Score: 0.6781609195402298
#
# Overall Average Validation Loss: 0.3066048711538315
# Overall Average Validation Accuracy: 0.9098000049591064

# %%
import matplotlib.pyplot as plt

# Assuming history is accessible from tb_cls.fit output
history = history.history  # Replace with appropriate method to access history

# Extract accuracy and loss for training and validation sets
train_acc = history['accuracy']  # Replace with actual metric names
val_acc = history['val_accuracy']
train_loss = history['loss']
val_loss = history['val_loss']

# Plotting accuracy
plt.figure(figsize=(10, 6))
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plotting accuracy
plt.figure(figsize=(10, 6))
plt.plot(train_loss, label='Training Logloss')
plt.plot(val_loss, label='Validation Logloss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs. Validation Logloss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # TabNet Model
#
# TabNet (Tabular Neural Network) is a neural network architecture designed specifically for tabular data, commonly encountered in structured data sets. It was introduced in the paper "TabNet: Attentive Interpretable Tabular Learning" by Sercan O. Arik and Tomas Pfister. TabNet is an interpretable and efficient neural network architecture that combines elements of deep learning with attention mechanisms and feature selection techniques. It aims to achieve state-of-the-art performance on tabular data while providing insights into feature importance and model decisions.
#
# #### Architecture:
#
# The architecture of TabNet consists of several key components:
#
# - Feature Embedding Layer: Converts categorical variables into dense representations suitable for neural networks. This layer often utilizes techniques like embedding layers or one-hot encoding followed by dense layers.
# - Feature Transformation Blocks: These blocks contain multiple sequential attention-based feature transformation steps. Each step performs feature selection and transformation using the features' interactions and dependencies.
# - Decision Steps: In each feature transformation block, decision steps apply feature-wise gating mechanisms to select relevant features and suppress irrelevant ones based on their importance.
# - Final Prediction Layer: The output of the feature transformation blocks is passed through a final prediction layer, typically consisting of fully connected layers followed by softmax or sigmoid activation functions for classification or regression tasks, respectively.
#
# #### Training Process:
#
# The training process involves optimizing the model parameters to minimize a defined loss function (e.g., cross-entropy loss for classification tasks). TabNet employs optimization techniques such as the Adam optimizer and learning rate scheduling to efficiently update the model parameters during training.
#
#
# <br><br>
#
# <table style="text-align: center; width: 80%; font-size: 16px; border-collapse: collapse;">
#     <caption>Accuracies over all folds</caption>
#     <tr>
#         <th style="border: 1px solid black;"> </th>
#         <th style="border: 1px solid black;">Fold 1</th>
#         <th style="border: 1px solid black;">Fold 2</th>
#         <th style="border: 1px solid black;">Fold 3</th>
#         <th style="border: 1px solid black;">Fold 4</th>
#         <th style="border: 1px solid black;">Fold 5</th>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black;">Best Epoch</th>
#         <td style="border: 1px solid black;">35</td>
#         <td style="border: 1px solid black;">45</td>
#         <td style="border: 1px solid black;">46</td>
#         <td style="border: 1px solid black;">41</td>
#         <td style="border: 1px solid black;">24</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black;">Final Validation LogLoss</th>
#         <td style="border: 1px solid black;">0.0438</td>
#         <td style="border: 1px solid black;">0.0623</td>
#         <td style="border: 1px solid black;">0.0626</td>
#         <td style="border: 1px solid black;">0.0466</td>
#         <td style="border: 1px solid black;">0.0651</td>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black;">Final Validation Accuracy</th>
#         <td style="border: 1px solid black;">0.980</td>
#         <td style="border: 1px solid black;">0.985</td>
#         <td style="border: 1px solid black;">0.978</td>
#         <td style="border: 1px solid black;">0.972</td>
#         <td style="border: 1px solid black;">0.982</td>
#     </tr>
# </table>

# %%
import torch
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.model_selection import KFold

# Flattening the target variable 'y'
y = y.flatten()

# KFold parameters
kf = KFold(n_splits=5, random_state=42, shuffle=True)

# Lists to store confusion matrix and evaluation metrics
y_true_all = []
y_pred_all = []

CV_score_array = []

# Loop over each fold
for fold_index, (train_index, test_index) in enumerate(kf.split(X)):
    X_train, X_valid = X[train_index], X[test_index]
    y_train, y_valid = y[train_index], y[test_index]

    # Initialize TabNetClassifier with parameters
    tb_cls = TabNetClassifier(optimizer_fn=torch.optim.Adam,
                              optimizer_params=dict(lr=1e-3),
                              scheduler_params={"step_size": 10, "gamma": 0.9},
                              scheduler_fn=torch.optim.lr_scheduler.StepLR,
                              mask_type='entmax')

    # Train the TabNet model
    history = tb_cls.fit(X_train, y_train,
                         eval_set=[(X_train, y_train), (X_valid, y_valid)],
                         eval_name=['train', 'valid'],
                         eval_metric=['accuracy', 'logloss'],
                         max_epochs=50, patience=25,
                         batch_size=28, drop_last=False)

    # Get predictions for validation data
    y_pred_prob = tb_cls.predict_proba(X_valid)[:, 1]  # Probabilities for class 1
    y_pred_class = (y_pred_prob > 0.5).astype(int)  # Convert probabilities to binary class predictions

    # Store true and predicted values for confusion matrix
    y_true_all.extend(y_valid)
    y_pred_all.extend(y_pred_class)

    # Store the best cost (loss) for each fold
    CV_score_array.append(tb_cls.best_cost)

    # Print fold results
    print(f"\nFold: {fold_index+1}")
    print(f"Best Cost (Log Loss) for Fold {fold_index+1}: {tb_cls.best_cost}")

# After all folds, calculate the overall confusion matrix
cm = confusion_matrix(y_true_all, y_pred_all)
accuracy = accuracy_score(y_true_all, y_pred_all)
precision = precision_score(y_true_all, y_pred_all)
recall = recall_score(y_true_all, y_pred_all)
f1 = f1_score(y_true_all, y_pred_all)

# Printing the overall confusion matrix and classification metrics
print(f"\nOverall Confusion Matrix:\n{cm}")
print(f"Overall Accuracy: {accuracy}")
print(f"Overall Precision: {precision}")
print(f"Overall Recall: {recall}")
print(f"Overall F1 Score: {f1}")

# Printing K-Fold evaluation results (best cost for each fold)
print(f"\nBest Cost (Log Loss) for each fold: {CV_score_array}")
# Out:
# epoch 0  | loss: 0.44046 | train_accuracy: 0.90625 | train_logloss: 0.33735 | valid_accuracy: 0.888   | valid_logloss: 0.35995 |  0:00:07s
# epoch 1  | loss: 0.28878 | train_accuracy: 0.914   | train_logloss: 0.25015 | valid_accuracy: 0.904   | valid_logloss: 0.26437 |  0:00:12s
# epoch 2  | loss: 0.25162 | train_accuracy: 0.918   | train_logloss: 0.21817 | valid_accuracy: 0.92    | valid_logloss: 0.20385 |  0:00:18s
# epoch 3  | loss: 0.2118  | train_accuracy: 0.9345  | train_logloss: 0.17948 | valid_accuracy: 0.927   | valid_logloss: 0.17601 |  0:00:23s
# epoch 4  | loss: 0.19284 | train_accuracy: 0.9425  | train_logloss: 0.16343 | valid_accuracy: 0.929   | valid_logloss: 0.16531 |  0:00:28s
# epoch 5  | loss: 0.16444 | train_accuracy: 0.94975 | train_logloss: 0.13076 | valid_accuracy: 0.951   | valid_logloss: 0.12297 |  0:00:33s
# epoch 6  | loss: 0.1583  | train_accuracy: 0.95825 | train_logloss: 0.11857 | valid_accuracy: 0.947   | valid_logloss: 0.12524 |  0:00:38s
# epoch 7  | loss: 0.14337 | train_accuracy: 0.95825 | train_logloss: 0.11737 | valid_accuracy: 0.958   | valid_logloss: 0.12759 |  0:00:44s
# epoch 8  | loss: 0.13659 | train_accuracy: 0.9625  | train_logloss: 0.10653 | valid_accuracy: 0.957   | valid_logloss: 0.11314 |  0:00:49s
# epoch 9  | loss: 0.13052 | train_accuracy: 0.96425 | train_logloss: 0.10426 | valid_accuracy: 0.965   | valid_logloss: 0.10023 |  0:00:54s
# epoch 10 | loss: 0.12592 | train_accuracy: 0.96775 | train_logloss: 0.09083 | valid_accuracy: 0.962   | valid_logloss: 0.08596 |  0:01:00s
# epoch 11 | loss: 0.12493 | train_accuracy: 0.97075 | train_logloss: 0.08393 | valid_accuracy: 0.973   | valid_logloss: 0.08027 |  0:01:05s
# epoch 12 | loss: 0.1174  | train_accuracy: 0.96975 | train_logloss: 0.08578 | valid_accuracy: 0.965   | valid_logloss: 0.09648 |  0:01:10s
# epoch 13 | loss: 0.11775 | train_accuracy: 0.969   | train_logloss: 0.08751 | valid_accuracy: 0.971   | valid_logloss: 0.07761 |  0:01:15s
# epoch 14 | loss: 0.1207  | train_accuracy: 0.974   | train_logloss: 0.07942 | valid_accuracy: 0.972   | valid_logloss: 0.07409 |  0:01:20s
# epoch 15 | loss: 0.11088 | train_accuracy: 0.97425 | train_logloss: 0.07591 | valid_accuracy: 0.974   | valid_logloss: 0.07692 |  0:01:26s
# epoch 16 | loss: 0.10285 | train_accuracy: 0.97475 | train_logloss: 0.0744  | valid_accuracy: 0.978   | valid_logloss: 0.06497 |  0:01:31s
# epoch 17 | loss: 0.10905 | train_accuracy: 0.97525 | train_logloss: 0.07253 | valid_accuracy: 0.977   | valid_logloss: 0.06181 |  0:01:36s
# epoch 18 | loss: 0.10501 | train_accuracy: 0.97725 | train_logloss: 0.0674  | valid_accuracy: 0.977   | valid_logloss: 0.06235 |  0:01:41s
# epoch 19 | loss: 0.10165 | train_accuracy: 0.97575 | train_logloss: 0.07274 | valid_accuracy: 0.98    | valid_logloss: 0.06723 |  0:01:46s
# epoch 20 | loss: 0.10131 | train_accuracy: 0.9735  | train_logloss: 0.06781 | valid_accuracy: 0.979   | valid_logloss: 0.05853 |  0:01:52s
# epoch 21 | loss: 0.09843 | train_accuracy: 0.97475 | train_logloss: 0.06569 | valid_accuracy: 0.976   | valid_logloss: 0.06553 |  0:01:57s
# epoch 22 | loss: 0.08949 | train_accuracy: 0.977   | train_logloss: 0.06332 | valid_accuracy: 0.977   | valid_logloss: 0.06314 |  0:02:02s
# epoch 23 | loss: 0.09102 | train_accuracy: 0.98125 | train_logloss: 0.05674 | valid_accuracy: 0.979   | valid_logloss: 0.05814 |  0:02:08s
# epoch 24 | loss: 0.09934 | train_accuracy: 0.97625 | train_logloss: 0.06954 | valid_accuracy: 0.975   | valid_logloss: 0.07523 |  0:02:13s
# epoch 25 | loss: 0.09343 | train_accuracy: 0.9805  | train_logloss: 0.06439 | valid_accuracy: 0.98    | valid_logloss: 0.0697  |  0:02:18s
# epoch 26 | loss: 0.08717 | train_accuracy: 0.9785  | train_logloss: 0.06068 | valid_accuracy: 0.974   | valid_logloss: 0.06705 |  0:02:24s
# epoch 27 | loss: 0.08674 | train_accuracy: 0.9815  | train_logloss: 0.0587  | valid_accuracy: 0.98    | valid_logloss: 0.06066 |  0:02:30s
# epoch 28 | loss: 0.08415 | train_accuracy: 0.9795  | train_logloss: 0.06025 | valid_accuracy: 0.975   | valid_logloss: 0.06635 |  0:02:37s
# epoch 29 | loss: 0.0797  | train_accuracy: 0.98225 | train_logloss: 0.05161 | valid_accuracy: 0.981   | valid_logloss: 0.05052 |  0:02:45s
# epoch 30 | loss: 0.08132 | train_accuracy: 0.98125 | train_logloss: 0.05351 | valid_accuracy: 0.981   | valid_logloss: 0.05427 |  0:02:51s
# epoch 31 | loss: 0.0898  | train_accuracy: 0.98075 | train_logloss: 0.05423 | valid_accuracy: 0.981   | valid_logloss: 0.05207 |  0:02:56s
# epoch 32 | loss: 0.07996 | train_accuracy: 0.98125 | train_logloss: 0.05286 | valid_accuracy: 0.981   | valid_logloss: 0.05351 |  0:03:03s
# epoch 33 | loss: 0.08374 | train_accuracy: 0.982   | train_logloss: 0.05158 | valid_accuracy: 0.981   | valid_logloss: 0.0531  |  0:03:07s
# epoch 34 | loss: 0.0823  | train_accuracy: 0.979   | train_logloss: 0.05698 | valid_accuracy: 0.977   | valid_logloss: 0.06263 |  0:03:12s
# epoch 35 | loss: 0.07784 | train_accuracy: 0.9815  | train_logloss: 0.05183 | valid_accuracy: 0.98    | valid_logloss: 0.05479 |  0:03:18s
# epoch 36 | loss: 0.08184 | train_accuracy: 0.9845  | train_logloss: 0.04824 | valid_accuracy: 0.983   | valid_logloss: 0.04823 |  0:03:23s
# epoch 37 | loss: 0.07764 | train_accuracy: 0.983   | train_logloss: 0.05033 | valid_accuracy: 0.982   | valid_logloss: 0.04972 |  0:03:29s
# epoch 38 | loss: 0.07615 | train_accuracy: 0.98475 | train_logloss: 0.04756 | valid_accuracy: 0.981   | valid_logloss: 0.05101 |  0:03:34s
# epoch 39 | loss: 0.0678  | train_accuracy: 0.9835  | train_logloss: 0.04846 | valid_accuracy: 0.983   | valid_logloss: 0.04871 |  0:03:38s
# epoch 40 | loss: 0.07606 | train_accuracy: 0.98525 | train_logloss: 0.04592 | valid_accuracy: 0.981   | valid_logloss: 0.04949 |  0:03:44s
# epoch 41 | loss: 0.07888 | train_accuracy: 0.983   | train_logloss: 0.05079 | valid_accuracy: 0.983   | valid_logloss: 0.04778 |  0:03:49s
# epoch 42 | loss: 0.07716 | train_accuracy: 0.985   | train_logloss: 0.04788 | valid_accuracy: 0.982   | valid_logloss: 0.0458  |  0:03:54s
# epoch 43 | loss: 0.07537 | train_accuracy: 0.98475 | train_logloss: 0.04743 | valid_accuracy: 0.985   | valid_logloss: 0.04608 |  0:04:00s
# epoch 44 | loss: 0.07229 | train_accuracy: 0.9855  | train_logloss: 0.04702 | valid_accuracy: 0.982   | valid_logloss: 0.05086 |  0:04:05s
# epoch 45 | loss: 0.07917 | train_accuracy: 0.985   | train_logloss: 0.04683 | valid_accuracy: 0.983   | valid_logloss: 0.0472  |  0:04:10s
# epoch 46 | loss: 0.08061 | train_accuracy: 0.9845  | train_logloss: 0.04731 | valid_accuracy: 0.984   | valid_logloss: 0.04726 |  0:04:15s
# epoch 47 | loss: 0.08085 | train_accuracy: 0.9845  | train_logloss: 0.04536 | valid_accuracy: 0.984   | valid_logloss: 0.0442  |  0:04:20s
# epoch 48 | loss: 0.08228 | train_accuracy: 0.98725 | train_logloss: 0.04441 | valid_accuracy: 0.986   | valid_logloss: 0.04297 |  0:04:26s
# epoch 49 | loss: 0.08176 | train_accuracy: 0.98625 | train_logloss: 0.04514 | valid_accuracy: 0.982   | valid_logloss: 0.04776 |  0:04:31s
# Stop training because you reached max_epochs = 50 with best_epoch = 48 and best_valid_logloss = 0.04297
#
# Fold: 1
# Best Cost (Log Loss) for Fold 1: 0.04296558195315969
# epoch 0  | loss: 0.44359 | train_accuracy: 0.90425 | train_logloss: 0.34401 | valid_accuracy: 0.906   | valid_logloss: 0.32785 |  0:00:07s
# epoch 1  | loss: 0.28856 | train_accuracy: 0.9115  | train_logloss: 0.24535 | valid_accuracy: 0.91    | valid_logloss: 0.25516 |  0:00:11s
# epoch 2  | loss: 0.23395 | train_accuracy: 0.9245  | train_logloss: 0.2135  | valid_accuracy: 0.913   | valid_logloss: 0.24279 |  0:00:16s
# epoch 3  | loss: 0.19919 | train_accuracy: 0.9415  | train_logloss: 0.18156 | valid_accuracy: 0.926   | valid_logloss: 0.19942 |  0:00:22s
# epoch 4  | loss: 0.17993 | train_accuracy: 0.9495  | train_logloss: 0.16626 | valid_accuracy: 0.938   | valid_logloss: 0.18045 |  0:00:27s
# epoch 5  | loss: 0.16321 | train_accuracy: 0.95525 | train_logloss: 0.13738 | valid_accuracy: 0.935   | valid_logloss: 0.18286 |  0:00:32s
# epoch 6  | loss: 0.14306 | train_accuracy: 0.9575  | train_logloss: 0.12442 | valid_accuracy: 0.945   | valid_logloss: 0.15779 |  0:00:37s
# epoch 7  | loss: 0.14019 | train_accuracy: 0.964   | train_logloss: 0.11088 | valid_accuracy: 0.948   | valid_logloss: 0.14258 |  0:00:42s
# epoch 8  | loss: 0.1186  | train_accuracy: 0.96825 | train_logloss: 0.09285 | valid_accuracy: 0.955   | valid_logloss: 0.1211  |  0:00:48s
# epoch 9  | loss: 0.1162  | train_accuracy: 0.9705  | train_logloss: 0.08482 | valid_accuracy: 0.957   | valid_logloss: 0.11378 |  0:00:53s
# epoch 10 | loss: 0.11588 | train_accuracy: 0.97125 | train_logloss: 0.08009 | valid_accuracy: 0.96    | valid_logloss: 0.1061  |  0:00:57s
# epoch 11 | loss: 0.11017 | train_accuracy: 0.97275 | train_logloss: 0.07576 | valid_accuracy: 0.963   | valid_logloss: 0.10295 |  0:01:03s
# epoch 12 | loss: 0.10461 | train_accuracy: 0.97375 | train_logloss: 0.07138 | valid_accuracy: 0.96    | valid_logloss: 0.10339 |  0:01:08s
# epoch 13 | loss: 0.09819 | train_accuracy: 0.978   | train_logloss: 0.06394 | valid_accuracy: 0.961   | valid_logloss: 0.09778 |  0:01:13s
# epoch 14 | loss: 0.10319 | train_accuracy: 0.9755  | train_logloss: 0.06577 | valid_accuracy: 0.962   | valid_logloss: 0.10452 |  0:01:19s
# epoch 15 | loss: 0.09268 | train_accuracy: 0.977   | train_logloss: 0.06452 | valid_accuracy: 0.965   | valid_logloss: 0.09182 |  0:01:23s
# epoch 16 | loss: 0.08134 | train_accuracy: 0.9775  | train_logloss: 0.06111 | valid_accuracy: 0.965   | valid_logloss: 0.08896 |  0:01:29s
# epoch 17 | loss: 0.09646 | train_accuracy: 0.98325 | train_logloss: 0.05658 | valid_accuracy: 0.971   | valid_logloss: 0.08289 |  0:01:34s
# epoch 18 | loss: 0.092   | train_accuracy: 0.98025 | train_logloss: 0.05921 | valid_accuracy: 0.965   | valid_logloss: 0.08806 |  0:01:39s
# epoch 19 | loss: 0.08977 | train_accuracy: 0.98175 | train_logloss: 0.05521 | valid_accuracy: 0.969   | valid_logloss: 0.08532 |  0:01:45s
# epoch 20 | loss: 0.0823  | train_accuracy: 0.98325 | train_logloss: 0.05256 | valid_accuracy: 0.966   | valid_logloss: 0.08182 |  0:01:49s
# epoch 21 | loss: 0.08054 | train_accuracy: 0.9825  | train_logloss: 0.05214 | valid_accuracy: 0.967   | valid_logloss: 0.07996 |  0:01:55s
# epoch 22 | loss: 0.08279 | train_accuracy: 0.98225 | train_logloss: 0.05231 | valid_accuracy: 0.97    | valid_logloss: 0.07583 |  0:02:00s
# epoch 23 | loss: 0.07738 | train_accuracy: 0.983   | train_logloss: 0.05145 | valid_accuracy: 0.97    | valid_logloss: 0.07719 |  0:02:05s
# epoch 24 | loss: 0.08365 | train_accuracy: 0.98325 | train_logloss: 0.04988 | valid_accuracy: 0.97    | valid_logloss: 0.07474 |  0:02:11s
# epoch 25 | loss: 0.08301 | train_accuracy: 0.985   | train_logloss: 0.04762 | valid_accuracy: 0.973   | valid_logloss: 0.07133 |  0:02:16s
# epoch 26 | loss: 0.0818  | train_accuracy: 0.98375 | train_logloss: 0.04811 | valid_accuracy: 0.971   | valid_logloss: 0.07391 |  0:02:21s
# epoch 27 | loss: 0.08593 | train_accuracy: 0.9855  | train_logloss: 0.04751 | valid_accuracy: 0.969   | valid_logloss: 0.07105 |  0:02:26s
# epoch 28 | loss: 0.07064 | train_accuracy: 0.984   | train_logloss: 0.04705 | valid_accuracy: 0.973   | valid_logloss: 0.07021 |  0:02:31s
# epoch 29 | loss: 0.07711 | train_accuracy: 0.9845  | train_logloss: 0.04741 | valid_accuracy: 0.973   | valid_logloss: 0.07573 |  0:02:37s
# epoch 30 | loss: 0.08038 | train_accuracy: 0.98525 | train_logloss: 0.04935 | valid_accuracy: 0.969   | valid_logloss: 0.08191 |  0:02:42s
# epoch 31 | loss: 0.07791 | train_accuracy: 0.98575 | train_logloss: 0.05019 | valid_accuracy: 0.969   | valid_logloss: 0.07918 |  0:02:46s
# epoch 32 | loss: 0.07188 | train_accuracy: 0.9855  | train_logloss: 0.04513 | valid_accuracy: 0.972   | valid_logloss: 0.06828 |  0:02:52s
# epoch 33 | loss: 0.07502 | train_accuracy: 0.98575 | train_logloss: 0.04531 | valid_accuracy: 0.972   | valid_logloss: 0.06919 |  0:02:57s
# epoch 34 | loss: 0.07436 | train_accuracy: 0.9855  | train_logloss: 0.04518 | valid_accuracy: 0.975   | valid_logloss: 0.0657  |  0:03:02s
# epoch 35 | loss: 0.07996 | train_accuracy: 0.986   | train_logloss: 0.04442 | valid_accuracy: 0.975   | valid_logloss: 0.0681  |  0:03:08s
# epoch 36 | loss: 0.07418 | train_accuracy: 0.98675 | train_logloss: 0.04278 | valid_accuracy: 0.977   | valid_logloss: 0.06421 |  0:03:13s
# epoch 37 | loss: 0.07508 | train_accuracy: 0.98625 | train_logloss: 0.04435 | valid_accuracy: 0.977   | valid_logloss: 0.06568 |  0:03:20s
# epoch 38 | loss: 0.07591 | train_accuracy: 0.98525 | train_logloss: 0.04472 | valid_accuracy: 0.975   | valid_logloss: 0.06739 |  0:03:24s
# epoch 39 | loss: 0.07767 | train_accuracy: 0.98475 | train_logloss: 0.04804 | valid_accuracy: 0.974   | valid_logloss: 0.0708  |  0:03:29s
# epoch 40 | loss: 0.0728  | train_accuracy: 0.98675 | train_logloss: 0.04273 | valid_accuracy: 0.975   | valid_logloss: 0.05959 |  0:03:35s
# epoch 41 | loss: 0.08589 | train_accuracy: 0.986   | train_logloss: 0.04508 | valid_accuracy: 0.976   | valid_logloss: 0.0622  |  0:03:40s
# epoch 42 | loss: 0.06685 | train_accuracy: 0.9845  | train_logloss: 0.0445  | valid_accuracy: 0.979   | valid_logloss: 0.05774 |  0:03:45s
# epoch 43 | loss: 0.06484 | train_accuracy: 0.98775 | train_logloss: 0.04142 | valid_accuracy: 0.977   | valid_logloss: 0.05763 |  0:03:50s
# epoch 44 | loss: 0.06356 | train_accuracy: 0.98775 | train_logloss: 0.04068 | valid_accuracy: 0.978   | valid_logloss: 0.05392 |  0:03:55s
# epoch 45 | loss: 0.07505 | train_accuracy: 0.987   | train_logloss: 0.04083 | valid_accuracy: 0.977   | valid_logloss: 0.05607 |  0:04:01s
# epoch 46 | loss: 0.069   | train_accuracy: 0.98725 | train_logloss: 0.04066 | valid_accuracy: 0.978   | valid_logloss: 0.05939 |  0:04:06s
# epoch 47 | loss: 0.06789 | train_accuracy: 0.9865  | train_logloss: 0.04214 | valid_accuracy: 0.975   | valid_logloss: 0.06084 |  0:04:10s
# epoch 48 | loss: 0.0678  | train_accuracy: 0.98575 | train_logloss: 0.04319 | valid_accuracy: 0.978   | valid_logloss: 0.05892 |  0:04:16s
# epoch 49 | loss: 0.06525 | train_accuracy: 0.98525 | train_logloss: 0.0431  | valid_accuracy: 0.977   | valid_logloss: 0.06161 |  0:04:21s
# Stop training because you reached max_epochs = 50 with best_epoch = 44 and best_valid_logloss = 0.05392
#
# Fold: 2
# Best Cost (Log Loss) for Fold 2: 0.053919981890334236
# epoch 0  | loss: 0.43386 | train_accuracy: 0.90925 | train_logloss: 0.3333  | valid_accuracy: 0.897   | valid_logloss: 0.34778 |  0:00:05s
# epoch 1  | loss: 0.27101 | train_accuracy: 0.91575 | train_logloss: 0.23383 | valid_accuracy: 0.911   | valid_logloss: 0.25018 |  0:00:10s
# epoch 2  | loss: 0.2439  | train_accuracy: 0.919   | train_logloss: 0.21303 | valid_accuracy: 0.906   | valid_logloss: 0.24021 |  0:00:15s
# epoch 3  | loss: 0.21233 | train_accuracy: 0.92825 | train_logloss: 0.18671 | valid_accuracy: 0.923   | valid_logloss: 0.21251 |  0:00:21s
# epoch 4  | loss: 0.18403 | train_accuracy: 0.9435  | train_logloss: 0.15137 | valid_accuracy: 0.941   | valid_logloss: 0.17605 |  0:00:26s
# epoch 5  | loss: 0.17471 | train_accuracy: 0.947   | train_logloss: 0.14796 | valid_accuracy: 0.939   | valid_logloss: 0.18014 |  0:00:32s
# epoch 6  | loss: 0.15462 | train_accuracy: 0.95025 | train_logloss: 0.12908 | valid_accuracy: 0.942   | valid_logloss: 0.14954 |  0:00:37s
# epoch 7  | loss: 0.14238 | train_accuracy: 0.956   | train_logloss: 0.11798 | valid_accuracy: 0.948   | valid_logloss: 0.14065 |  0:00:42s
# epoch 8  | loss: 0.13474 | train_accuracy: 0.961   | train_logloss: 0.10012 | valid_accuracy: 0.958   | valid_logloss: 0.11781 |  0:00:47s
# epoch 9  | loss: 0.13037 | train_accuracy: 0.96375 | train_logloss: 0.09796 | valid_accuracy: 0.956   | valid_logloss: 0.12675 |  0:00:52s
# epoch 10 | loss: 0.11526 | train_accuracy: 0.96925 | train_logloss: 0.08219 | valid_accuracy: 0.961   | valid_logloss: 0.1094  |  0:00:57s
# epoch 11 | loss: 0.10841 | train_accuracy: 0.969   | train_logloss: 0.08109 | valid_accuracy: 0.964   | valid_logloss: 0.1101  |  0:01:03s
# epoch 12 | loss: 0.10744 | train_accuracy: 0.973   | train_logloss: 0.07533 | valid_accuracy: 0.963   | valid_logloss: 0.11198 |  0:01:07s
# epoch 13 | loss: 0.11173 | train_accuracy: 0.9765  | train_logloss: 0.07164 | valid_accuracy: 0.969   | valid_logloss: 0.09411 |  0:01:13s
# epoch 14 | loss: 0.10144 | train_accuracy: 0.974   | train_logloss: 0.07066 | valid_accuracy: 0.969   | valid_logloss: 0.09578 |  0:01:18s
# epoch 15 | loss: 0.10635 | train_accuracy: 0.9755  | train_logloss: 0.0681  | valid_accuracy: 0.965   | valid_logloss: 0.09751 |  0:01:22s
# epoch 16 | loss: 0.09686 | train_accuracy: 0.97925 | train_logloss: 0.06428 | valid_accuracy: 0.971   | valid_logloss: 0.09182 |  0:01:28s
# epoch 17 | loss: 0.09404 | train_accuracy: 0.979   | train_logloss: 0.06225 | valid_accuracy: 0.971   | valid_logloss: 0.08502 |  0:01:33s
# epoch 18 | loss: 0.09335 | train_accuracy: 0.97975 | train_logloss: 0.0618  | valid_accuracy: 0.975   | valid_logloss: 0.07869 |  0:01:38s
# epoch 19 | loss: 0.08984 | train_accuracy: 0.97725 | train_logloss: 0.06324 | valid_accuracy: 0.973   | valid_logloss: 0.08379 |  0:01:44s
# epoch 20 | loss: 0.09188 | train_accuracy: 0.97975 | train_logloss: 0.05944 | valid_accuracy: 0.974   | valid_logloss: 0.08416 |  0:01:48s
# epoch 21 | loss: 0.09713 | train_accuracy: 0.979   | train_logloss: 0.05985 | valid_accuracy: 0.97    | valid_logloss: 0.08736 |  0:01:54s
# epoch 22 | loss: 0.09063 | train_accuracy: 0.982   | train_logloss: 0.05583 | valid_accuracy: 0.972   | valid_logloss: 0.08501 |  0:01:59s
# epoch 23 | loss: 0.09834 | train_accuracy: 0.98075 | train_logloss: 0.05801 | valid_accuracy: 0.972   | valid_logloss: 0.08238 |  0:02:04s
# epoch 24 | loss: 0.07941 | train_accuracy: 0.98075 | train_logloss: 0.05523 | valid_accuracy: 0.972   | valid_logloss: 0.08482 |  0:02:10s
# epoch 25 | loss: 0.08643 | train_accuracy: 0.978   | train_logloss: 0.05761 | valid_accuracy: 0.974   | valid_logloss: 0.08447 |  0:02:14s
# epoch 26 | loss: 0.09288 | train_accuracy: 0.9785  | train_logloss: 0.05761 | valid_accuracy: 0.968   | valid_logloss: 0.0859  |  0:02:19s
# epoch 27 | loss: 0.08793 | train_accuracy: 0.9815  | train_logloss: 0.05203 | valid_accuracy: 0.971   | valid_logloss: 0.08106 |  0:02:25s
# epoch 28 | loss: 0.0808  | train_accuracy: 0.98275 | train_logloss: 0.05152 | valid_accuracy: 0.973   | valid_logloss: 0.07925 |  0:02:30s
# epoch 29 | loss: 0.08841 | train_accuracy: 0.9795  | train_logloss: 0.0539  | valid_accuracy: 0.97    | valid_logloss: 0.083   |  0:02:35s
# epoch 30 | loss: 0.08595 | train_accuracy: 0.98225 | train_logloss: 0.04989 | valid_accuracy: 0.977   | valid_logloss: 0.07597 |  0:02:40s
# epoch 31 | loss: 0.08185 | train_accuracy: 0.98325 | train_logloss: 0.04777 | valid_accuracy: 0.974   | valid_logloss: 0.07915 |  0:02:45s
# epoch 32 | loss: 0.07074 | train_accuracy: 0.984   | train_logloss: 0.04815 | valid_accuracy: 0.975   | valid_logloss: 0.08085 |  0:02:51s
# epoch 33 | loss: 0.0859  | train_accuracy: 0.9815  | train_logloss: 0.05121 | valid_accuracy: 0.969   | valid_logloss: 0.08706 |  0:02:56s
# epoch 34 | loss: 0.0745  | train_accuracy: 0.9835  | train_logloss: 0.04867 | valid_accuracy: 0.974   | valid_logloss: 0.07869 |  0:03:01s
# epoch 35 | loss: 0.06628 | train_accuracy: 0.9835  | train_logloss: 0.04939 | valid_accuracy: 0.973   | valid_logloss: 0.07834 |  0:03:06s
# epoch 36 | loss: 0.0779  | train_accuracy: 0.986   | train_logloss: 0.04718 | valid_accuracy: 0.975   | valid_logloss: 0.07982 |  0:03:11s
# epoch 37 | loss: 0.07346 | train_accuracy: 0.9845  | train_logloss: 0.04858 | valid_accuracy: 0.977   | valid_logloss: 0.07751 |  0:03:16s
# epoch 38 | loss: 0.08539 | train_accuracy: 0.98475 | train_logloss: 0.049   | valid_accuracy: 0.976   | valid_logloss: 0.07615 |  0:03:21s
# epoch 39 | loss: 0.07715 | train_accuracy: 0.98525 | train_logloss: 0.04614 | valid_accuracy: 0.975   | valid_logloss: 0.07378 |  0:03:26s
# epoch 40 | loss: 0.07741 | train_accuracy: 0.9845  | train_logloss: 0.04736 | valid_accuracy: 0.975   | valid_logloss: 0.07201 |  0:03:32s
# epoch 41 | loss: 0.07315 | train_accuracy: 0.98575 | train_logloss: 0.04627 | valid_accuracy: 0.976   | valid_logloss: 0.07305 |  0:03:37s
# epoch 42 | loss: 0.07999 | train_accuracy: 0.98375 | train_logloss: 0.04543 | valid_accuracy: 0.976   | valid_logloss: 0.07428 |  0:03:43s
# epoch 43 | loss: 0.06824 | train_accuracy: 0.98425 | train_logloss: 0.04674 | valid_accuracy: 0.978   | valid_logloss: 0.07038 |  0:03:48s
# epoch 44 | loss: 0.06925 | train_accuracy: 0.98475 | train_logloss: 0.04381 | valid_accuracy: 0.977   | valid_logloss: 0.06926 |  0:03:53s
# epoch 45 | loss: 0.06591 | train_accuracy: 0.985   | train_logloss: 0.04314 | valid_accuracy: 0.977   | valid_logloss: 0.0692  |  0:03:59s
# epoch 46 | loss: 0.0712  | train_accuracy: 0.98525 | train_logloss: 0.04317 | valid_accuracy: 0.976   | valid_logloss: 0.07356 |  0:04:04s
# epoch 47 | loss: 0.07443 | train_accuracy: 0.98675 | train_logloss: 0.0426  | valid_accuracy: 0.977   | valid_logloss: 0.07135 |  0:04:09s
# epoch 48 | loss: 0.06958 | train_accuracy: 0.98575 | train_logloss: 0.04358 | valid_accuracy: 0.976   | valid_logloss: 0.07088 |  0:04:14s
# epoch 49 | loss: 0.06971 | train_accuracy: 0.986   | train_logloss: 0.04278 | valid_accuracy: 0.977   | valid_logloss: 0.069   |  0:04:19s
# Stop training because you reached max_epochs = 50 with best_epoch = 49 and best_valid_logloss = 0.069
#
# Fold: 3
# Best Cost (Log Loss) for Fold 3: 0.0690041386175344
# epoch 0  | loss: 0.44833 | train_accuracy: 0.903   | train_logloss: 0.34552 | valid_accuracy: 0.918   | valid_logloss: 0.3159  |  0:00:05s
# epoch 1  | loss: 0.29446 | train_accuracy: 0.9165  | train_logloss: 0.24468 | valid_accuracy: 0.933   | valid_logloss: 0.23307 |  0:00:10s
# epoch 2  | loss: 0.24457 | train_accuracy: 0.9265  | train_logloss: 0.20649 | valid_accuracy: 0.931   | valid_logloss: 0.19887 |  0:00:15s
# epoch 3  | loss: 0.20842 | train_accuracy: 0.93    | train_logloss: 0.19068 | valid_accuracy: 0.932   | valid_logloss: 0.17795 |  0:00:21s
# epoch 4  | loss: 0.18837 | train_accuracy: 0.93775 | train_logloss: 0.16437 | valid_accuracy: 0.935   | valid_logloss: 0.15732 |  0:00:25s
# epoch 5  | loss: 0.17555 | train_accuracy: 0.94975 | train_logloss: 0.13224 | valid_accuracy: 0.944   | valid_logloss: 0.14078 |  0:00:31s
# epoch 6  | loss: 0.15581 | train_accuracy: 0.94875 | train_logloss: 0.12737 | valid_accuracy: 0.944   | valid_logloss: 0.13768 |  0:00:36s
# epoch 7  | loss: 0.15231 | train_accuracy: 0.95325 | train_logloss: 0.11686 | valid_accuracy: 0.956   | valid_logloss: 0.12193 |  0:00:42s
# epoch 8  | loss: 0.1437  | train_accuracy: 0.95575 | train_logloss: 0.117   | valid_accuracy: 0.956   | valid_logloss: 0.10184 |  0:00:48s
# epoch 9  | loss: 0.12595 | train_accuracy: 0.962   | train_logloss: 0.10241 | valid_accuracy: 0.97    | valid_logloss: 0.08998 |  0:00:52s
# epoch 10 | loss: 0.12887 | train_accuracy: 0.96725 | train_logloss: 0.09078 | valid_accuracy: 0.974   | valid_logloss: 0.08547 |  0:00:57s
# epoch 11 | loss: 0.1189  | train_accuracy: 0.96875 | train_logloss: 0.08734 | valid_accuracy: 0.973   | valid_logloss: 0.08689 |  0:01:03s
# epoch 12 | loss: 0.10717 | train_accuracy: 0.973   | train_logloss: 0.0784  | valid_accuracy: 0.974   | valid_logloss: 0.0794  |  0:01:08s
# epoch 13 | loss: 0.10633 | train_accuracy: 0.974   | train_logloss: 0.07189 | valid_accuracy: 0.978   | valid_logloss: 0.07006 |  0:01:13s
# epoch 14 | loss: 0.11027 | train_accuracy: 0.97275 | train_logloss: 0.07077 | valid_accuracy: 0.983   | valid_logloss: 0.06517 |  0:01:18s
# epoch 15 | loss: 0.09929 | train_accuracy: 0.9735  | train_logloss: 0.07212 | valid_accuracy: 0.978   | valid_logloss: 0.07072 |  0:01:23s
# epoch 16 | loss: 0.10397 | train_accuracy: 0.976   | train_logloss: 0.06904 | valid_accuracy: 0.98    | valid_logloss: 0.06575 |  0:01:29s
# epoch 17 | loss: 0.09677 | train_accuracy: 0.97725 | train_logloss: 0.06581 | valid_accuracy: 0.981   | valid_logloss: 0.06384 |  0:01:33s
# epoch 18 | loss: 0.09393 | train_accuracy: 0.97725 | train_logloss: 0.06384 | valid_accuracy: 0.98    | valid_logloss: 0.06124 |  0:01:38s
# epoch 19 | loss: 0.09368 | train_accuracy: 0.97675 | train_logloss: 0.06163 | valid_accuracy: 0.983   | valid_logloss: 0.05967 |  0:01:44s
# epoch 20 | loss: 0.09105 | train_accuracy: 0.9775  | train_logloss: 0.06037 | valid_accuracy: 0.984   | valid_logloss: 0.05697 |  0:01:49s
# epoch 21 | loss: 0.09099 | train_accuracy: 0.9765  | train_logloss: 0.06049 | valid_accuracy: 0.984   | valid_logloss: 0.05825 |  0:01:54s
# epoch 22 | loss: 0.08805 | train_accuracy: 0.97825 | train_logloss: 0.05948 | valid_accuracy: 0.985   | valid_logloss: 0.05662 |  0:01:59s
# epoch 23 | loss: 0.08644 | train_accuracy: 0.979   | train_logloss: 0.05709 | valid_accuracy: 0.985   | valid_logloss: 0.05606 |  0:02:04s
# epoch 24 | loss: 0.09375 | train_accuracy: 0.97875 | train_logloss: 0.05698 | valid_accuracy: 0.986   | valid_logloss: 0.05568 |  0:02:10s
# epoch 25 | loss: 0.08565 | train_accuracy: 0.9785  | train_logloss: 0.05635 | valid_accuracy: 0.984   | valid_logloss: 0.05631 |  0:02:15s
# epoch 26 | loss: 0.08791 | train_accuracy: 0.98125 | train_logloss: 0.05492 | valid_accuracy: 0.984   | valid_logloss: 0.05384 |  0:02:19s
# epoch 27 | loss: 0.08777 | train_accuracy: 0.981   | train_logloss: 0.05444 | valid_accuracy: 0.983   | valid_logloss: 0.05291 |  0:02:25s
# epoch 28 | loss: 0.0855  | train_accuracy: 0.98225 | train_logloss: 0.05295 | valid_accuracy: 0.984   | valid_logloss: 0.05267 |  0:02:30s
# epoch 29 | loss: 0.07579 | train_accuracy: 0.98225 | train_logloss: 0.05213 | valid_accuracy: 0.985   | valid_logloss: 0.05034 |  0:02:35s
# epoch 30 | loss: 0.08387 | train_accuracy: 0.9805  | train_logloss: 0.05355 | valid_accuracy: 0.985   | valid_logloss: 0.052   |  0:02:41s
# epoch 31 | loss: 0.08835 | train_accuracy: 0.97975 | train_logloss: 0.05504 | valid_accuracy: 0.985   | valid_logloss: 0.05306 |  0:02:45s
# epoch 32 | loss: 0.07611 | train_accuracy: 0.9825  | train_logloss: 0.0499  | valid_accuracy: 0.986   | valid_logloss: 0.05082 |  0:02:51s
# epoch 33 | loss: 0.08035 | train_accuracy: 0.98    | train_logloss: 0.05141 | valid_accuracy: 0.985   | valid_logloss: 0.05196 |  0:02:56s
# epoch 34 | loss: 0.07721 | train_accuracy: 0.98075 | train_logloss: 0.04995 | valid_accuracy: 0.986   | valid_logloss: 0.05042 |  0:03:00s
# epoch 35 | loss: 0.08628 | train_accuracy: 0.98275 | train_logloss: 0.04747 | valid_accuracy: 0.984   | valid_logloss: 0.04922 |  0:03:06s
# epoch 36 | loss: 0.07852 | train_accuracy: 0.98325 | train_logloss: 0.04731 | valid_accuracy: 0.987   | valid_logloss: 0.04779 |  0:03:11s
# epoch 37 | loss: 0.07658 | train_accuracy: 0.983   | train_logloss: 0.04711 | valid_accuracy: 0.988   | valid_logloss: 0.04618 |  0:03:16s
# epoch 38 | loss: 0.07363 | train_accuracy: 0.98325 | train_logloss: 0.04612 | valid_accuracy: 0.987   | valid_logloss: 0.04767 |  0:03:21s
# epoch 39 | loss: 0.07476 | train_accuracy: 0.9825  | train_logloss: 0.04822 | valid_accuracy: 0.986   | valid_logloss: 0.05145 |  0:03:26s
# epoch 40 | loss: 0.06692 | train_accuracy: 0.9845  | train_logloss: 0.04654 | valid_accuracy: 0.987   | valid_logloss: 0.05129 |  0:03:31s
# epoch 41 | loss: 0.07738 | train_accuracy: 0.9845  | train_logloss: 0.04408 | valid_accuracy: 0.987   | valid_logloss: 0.04863 |  0:03:36s
# epoch 42 | loss: 0.0706  | train_accuracy: 0.98325 | train_logloss: 0.04526 | valid_accuracy: 0.985   | valid_logloss: 0.05076 |  0:03:41s
# epoch 43 | loss: 0.0773  | train_accuracy: 0.98375 | train_logloss: 0.04446 | valid_accuracy: 0.988   | valid_logloss: 0.04878 |  0:03:47s
# epoch 44 | loss: 0.07552 | train_accuracy: 0.98325 | train_logloss: 0.04567 | valid_accuracy: 0.986   | valid_logloss: 0.0514  |  0:03:51s
# epoch 45 | loss: 0.06939 | train_accuracy: 0.98425 | train_logloss: 0.04255 | valid_accuracy: 0.988   | valid_logloss: 0.05064 |  0:03:56s
# epoch 46 | loss: 0.07444 | train_accuracy: 0.983   | train_logloss: 0.0437  | valid_accuracy: 0.986   | valid_logloss: 0.05145 |  0:04:02s
# epoch 47 | loss: 0.07761 | train_accuracy: 0.9835  | train_logloss: 0.04457 | valid_accuracy: 0.985   | valid_logloss: 0.05244 |  0:04:06s
# epoch 48 | loss: 0.07318 | train_accuracy: 0.98425 | train_logloss: 0.04251 | valid_accuracy: 0.985   | valid_logloss: 0.05056 |  0:04:13s
# epoch 49 | loss: 0.07015 | train_accuracy: 0.983   | train_logloss: 0.04497 | valid_accuracy: 0.985   | valid_logloss: 0.05176 |  0:04:18s
# Stop training because you reached max_epochs = 50 with best_epoch = 37 and best_valid_logloss = 0.04618
#
# Fold: 4
# Best Cost (Log Loss) for Fold 4: 0.04617689224316412
# epoch 0  | loss: 0.45549 | train_accuracy: 0.9045  | train_logloss: 0.34512 | valid_accuracy: 0.909   | valid_logloss: 0.33484 |  0:00:04s
# epoch 1  | loss: 0.29543 | train_accuracy: 0.903   | train_logloss: 0.25547 | valid_accuracy: 0.909   | valid_logloss: 0.26003 |  0:00:10s
# epoch 2  | loss: 0.24963 | train_accuracy: 0.913   | train_logloss: 0.20737 | valid_accuracy: 0.921   | valid_logloss: 0.1929  |  0:00:15s
# epoch 3  | loss: 0.21193 | train_accuracy: 0.92525 | train_logloss: 0.2027  | valid_accuracy: 0.941   | valid_logloss: 0.16013 |  0:00:20s
# epoch 4  | loss: 0.19215 | train_accuracy: 0.93525 | train_logloss: 0.17388 | valid_accuracy: 0.952   | valid_logloss: 0.15006 |  0:00:25s
# epoch 5  | loss: 0.1772  | train_accuracy: 0.94025 | train_logloss: 0.16219 | valid_accuracy: 0.951   | valid_logloss: 0.13692 |  0:00:30s
# epoch 6  | loss: 0.17445 | train_accuracy: 0.9425  | train_logloss: 0.15114 | valid_accuracy: 0.951   | valid_logloss: 0.12645 |  0:00:35s
# epoch 7  | loss: 0.15878 | train_accuracy: 0.9525  | train_logloss: 0.13138 | valid_accuracy: 0.958   | valid_logloss: 0.12232 |  0:00:40s
# epoch 8  | loss: 0.14994 | train_accuracy: 0.95725 | train_logloss: 0.11862 | valid_accuracy: 0.962   | valid_logloss: 0.10681 |  0:00:45s
# epoch 9  | loss: 0.13957 | train_accuracy: 0.96175 | train_logloss: 0.11279 | valid_accuracy: 0.972   | valid_logloss: 0.09853 |  0:00:50s
# epoch 10 | loss: 0.13097 | train_accuracy: 0.96175 | train_logloss: 0.09903 | valid_accuracy: 0.972   | valid_logloss: 0.09368 |  0:00:55s
# epoch 11 | loss: 0.1272  | train_accuracy: 0.9665  | train_logloss: 0.08914 | valid_accuracy: 0.97    | valid_logloss: 0.09489 |  0:01:01s
# epoch 12 | loss: 0.13267 | train_accuracy: 0.9685  | train_logloss: 0.08745 | valid_accuracy: 0.973   | valid_logloss: 0.09601 |  0:01:07s
# epoch 13 | loss: 0.11523 | train_accuracy: 0.96675 | train_logloss: 0.08996 | valid_accuracy: 0.969   | valid_logloss: 0.0953  |  0:01:11s
# epoch 14 | loss: 0.11565 | train_accuracy: 0.971   | train_logloss: 0.07979 | valid_accuracy: 0.972   | valid_logloss: 0.08623 |  0:01:17s
# epoch 15 | loss: 0.11024 | train_accuracy: 0.971   | train_logloss: 0.07898 | valid_accuracy: 0.971   | valid_logloss: 0.09207 |  0:01:22s
# epoch 16 | loss: 0.10322 | train_accuracy: 0.973   | train_logloss: 0.07313 | valid_accuracy: 0.973   | valid_logloss: 0.08804 |  0:01:27s
# epoch 17 | loss: 0.09901 | train_accuracy: 0.97475 | train_logloss: 0.07195 | valid_accuracy: 0.971   | valid_logloss: 0.09214 |  0:01:32s
# epoch 18 | loss: 0.10194 | train_accuracy: 0.975   | train_logloss: 0.06638 | valid_accuracy: 0.973   | valid_logloss: 0.08867 |  0:01:37s
# epoch 19 | loss: 0.0944  | train_accuracy: 0.978   | train_logloss: 0.06452 | valid_accuracy: 0.972   | valid_logloss: 0.08858 |  0:01:42s
# epoch 20 | loss: 0.10063 | train_accuracy: 0.9775  | train_logloss: 0.0646  | valid_accuracy: 0.972   | valid_logloss: 0.08786 |  0:01:47s
# epoch 21 | loss: 0.09489 | train_accuracy: 0.98    | train_logloss: 0.05886 | valid_accuracy: 0.972   | valid_logloss: 0.08586 |  0:01:52s
# epoch 22 | loss: 0.10257 | train_accuracy: 0.97875 | train_logloss: 0.06442 | valid_accuracy: 0.976   | valid_logloss: 0.08896 |  0:01:58s
# epoch 23 | loss: 0.09699 | train_accuracy: 0.98075 | train_logloss: 0.05725 | valid_accuracy: 0.976   | valid_logloss: 0.08332 |  0:02:02s
# epoch 24 | loss: 0.09258 | train_accuracy: 0.9815  | train_logloss: 0.0551  | valid_accuracy: 0.975   | valid_logloss: 0.08593 |  0:02:07s
# epoch 25 | loss: 0.08915 | train_accuracy: 0.98125 | train_logloss: 0.05657 | valid_accuracy: 0.979   | valid_logloss: 0.08638 |  0:02:13s
# epoch 26 | loss: 0.08432 | train_accuracy: 0.983   | train_logloss: 0.05241 | valid_accuracy: 0.977   | valid_logloss: 0.08351 |  0:02:18s
# epoch 27 | loss: 0.07653 | train_accuracy: 0.98325 | train_logloss: 0.04922 | valid_accuracy: 0.979   | valid_logloss: 0.08241 |  0:02:23s
# epoch 28 | loss: 0.08118 | train_accuracy: 0.98325 | train_logloss: 0.05216 | valid_accuracy: 0.978   | valid_logloss: 0.08754 |  0:02:28s
# epoch 29 | loss: 0.0786  | train_accuracy: 0.983   | train_logloss: 0.0531  | valid_accuracy: 0.978   | valid_logloss: 0.09038 |  0:02:33s
# epoch 30 | loss: 0.07515 | train_accuracy: 0.98425 | train_logloss: 0.04844 | valid_accuracy: 0.979   | valid_logloss: 0.07989 |  0:02:38s
# epoch 31 | loss: 0.08    | train_accuracy: 0.98325 | train_logloss: 0.05394 | valid_accuracy: 0.976   | valid_logloss: 0.08718 |  0:02:43s
# epoch 32 | loss: 0.08015 | train_accuracy: 0.983   | train_logloss: 0.0511  | valid_accuracy: 0.981   | valid_logloss: 0.08413 |  0:02:48s
# epoch 33 | loss: 0.07357 | train_accuracy: 0.98375 | train_logloss: 0.04656 | valid_accuracy: 0.978   | valid_logloss: 0.0854  |  0:02:54s
# epoch 34 | loss: 0.08171 | train_accuracy: 0.984   | train_logloss: 0.04827 | valid_accuracy: 0.978   | valid_logloss: 0.08721 |  0:02:58s
# epoch 35 | loss: 0.06847 | train_accuracy: 0.9835  | train_logloss: 0.04762 | valid_accuracy: 0.974   | valid_logloss: 0.08945 |  0:03:04s
# epoch 36 | loss: 0.0815  | train_accuracy: 0.98475 | train_logloss: 0.0453  | valid_accuracy: 0.974   | valid_logloss: 0.08624 |  0:03:09s
# epoch 37 | loss: 0.06318 | train_accuracy: 0.9855  | train_logloss: 0.04586 | valid_accuracy: 0.977   | valid_logloss: 0.08749 |  0:03:14s
# epoch 38 | loss: 0.07996 | train_accuracy: 0.9845  | train_logloss: 0.04825 | valid_accuracy: 0.979   | valid_logloss: 0.08604 |  0:03:19s
# epoch 39 | loss: 0.06678 | train_accuracy: 0.98575 | train_logloss: 0.04226 | valid_accuracy: 0.978   | valid_logloss: 0.07805 |  0:03:24s
# epoch 40 | loss: 0.07476 | train_accuracy: 0.9865  | train_logloss: 0.04266 | valid_accuracy: 0.98    | valid_logloss: 0.08126 |  0:03:29s
# epoch 41 | loss: 0.08374 | train_accuracy: 0.98525 | train_logloss: 0.04447 | valid_accuracy: 0.982   | valid_logloss: 0.08097 |  0:03:35s
# epoch 42 | loss: 0.06351 | train_accuracy: 0.98675 | train_logloss: 0.04172 | valid_accuracy: 0.98    | valid_logloss: 0.07586 |  0:03:39s
# epoch 43 | loss: 0.07709 | train_accuracy: 0.98625 | train_logloss: 0.04128 | valid_accuracy: 0.978   | valid_logloss: 0.07689 |  0:03:45s
# epoch 44 | loss: 0.06883 | train_accuracy: 0.98675 | train_logloss: 0.04216 | valid_accuracy: 0.981   | valid_logloss: 0.0803  |  0:03:50s
# epoch 45 | loss: 0.07255 | train_accuracy: 0.987   | train_logloss: 0.03977 | valid_accuracy: 0.981   | valid_logloss: 0.07925 |  0:03:55s
# epoch 46 | loss: 0.06438 | train_accuracy: 0.98525 | train_logloss: 0.04336 | valid_accuracy: 0.982   | valid_logloss: 0.08254 |  0:04:00s
# epoch 47 | loss: 0.07081 | train_accuracy: 0.9865  | train_logloss: 0.04246 | valid_accuracy: 0.98    | valid_logloss: 0.07899 |  0:04:05s
# epoch 48 | loss: 0.06169 | train_accuracy: 0.98675 | train_logloss: 0.04045 | valid_accuracy: 0.98    | valid_logloss: 0.0805  |  0:04:10s
# epoch 49 | loss: 0.07106 | train_accuracy: 0.98625 | train_logloss: 0.04122 | valid_accuracy: 0.98    | valid_logloss: 0.08211 |  0:04:16s
# Stop training because you reached max_epochs = 50 with best_epoch = 42 and best_valid_logloss = 0.07586
#
# Fold: 5
# Best Cost (Log Loss) for Fold 5: 0.07586129888931036
#
# Overall Confusion Matrix:
# [[4510   10]
#  [  81  399]]
# Overall Accuracy: 0.9818
# Overall Precision: 0.9755501222493888
# Overall Recall: 0.83125
# Overall F1 Score: 0.8976377952755905
#
# Best Cost (Log Loss) for each fold: [0.04296558195315969, 0.053919981890334236, 0.0690041386175344, 0.04617689224316412, 0.07586129888931036]

# %%
import matplotlib.pyplot as plt

# history accessible from tb_cls.fit output
history = tb_cls.history

# Extract accuracy and loss for training and validation sets
train_acc = history['train_accuracy']
val_acc = history['valid_accuracy']
train_loss = history['train_logloss']
val_loss = history['valid_logloss']

# Plotting accuracy
plt.figure(figsize=(10, 6))
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plotting accuracy
plt.figure(figsize=(10, 6))
plt.plot(train_loss, label='Training Logloss')
plt.plot(val_loss, label='Validation Logloss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs. Validation Logloss')
plt.legend()
plt.grid(True)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# Define the path in Google Drive
save_path = '/content/drive/MyDrive/saved_models/best_model'

# Save the model
tb_cls.save_model(save_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Successfully saved model at /content/drive/MyDrive/saved_models/best_model.zip
# '/content/drive/MyDrive/saved_models/best_model.zip'

# %% [markdown]
# # Wide & Deep neural network architecture
#
# This implements a Wide & Deep neural network architecture using TensorFlow's Keras API for binary classification tasks.
#
# ### Components of the Model:
#
# #### Normalization of Data:
#
# - The input data is normalized using mean and standard deviation calculated from the training data. This step helps in stabilizing the training process and improving convergence.
#
# #### Wide Component:
#
# - The wide component is a linear model that directly connects the input features to the output layer without any non-linear transformations. It is represented by a single Dense layer.
#
# #### Deep Component:
#
# - The deep component is a neural network consisting of multiple layers. Each layer is followed by Batch Normalization, LeakyReLU activation, and Dropout for regularization.
# - It comprises three Dense layers with 128, 64, and 32 units, respectively.
#
# #### Combining Wide and Deep Components:
#
# - The outputs from the wide and deep components are concatenated using the Concatenate layer.
# - This allows the model to learn both low-level and high-level feature representations simultaneously.
#
# #### Final Output Layer:
#
# - The concatenated output is passed through a final Dense layer with a sigmoid activation function, which outputs the predicted probability of the positive class (binary classification).
#
# # Metrics
#
# - Training Accuracy: 0.9715
# - Training Loss: 0.0752
# - val_accuracy: 0.9760
# - val_loss: 0.0531
# - learning_rate: 1.0000e-05

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, Concatenate, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

# Normalize the data
X_train = np.array(X_train).astype('float32')
X_test = np.array(X_test).astype('float32')

mean = X_train.mean(axis=0)
std = X_train.std(axis=0)

X_train -= mean
X_train /= std
X_test -= mean
X_test /= std

# Define input layers
inputs = Input(shape=(12,))

# Wide component (linear model)
wide_output = Dense(1)(inputs)

# Deep component (neural network)
deep_layer1 = Dense(128)(inputs)
deep_layer1 = BatchNormalization()(deep_layer1)
deep_layer1 = LeakyReLU()(deep_layer1)
deep_layer1 = Dropout(0.3)(deep_layer1)

deep_layer2 = Dense(64)(deep_layer1)
deep_layer2 = BatchNormalization()(deep_layer2)
deep_layer2 = LeakyReLU()(deep_layer2)
deep_layer2 = Dropout(0.3)(deep_layer2)

deep_layer3 = Dense(32)(deep_layer2)
deep_layer3 = BatchNormalization()(deep_layer3)
deep_layer3 = LeakyReLU()(deep_layer3)
deep_layer3 = Dropout(0.3)(deep_layer3)

deep_output = Dense(1)(deep_layer3)

# Combine wide and deep components
combined = Concatenate()([wide_output, deep_output])

# Final output layer
final_output = Dense(1, activation='sigmoid')(combined)

# Define model
model_wd = Model(inputs=inputs, outputs=final_output)

# Compile model with a lower learning rate and class weighting
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_wd.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

# Train model
history = model_wd.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stopping, reduce_lr]
)

# Extracting predictions on the validation set
y_pred_prob = model_wd.predict(X_test)
y_pred_class = (y_pred_prob > 0.5).astype(int)  # Convert probabilities to binary predictions

# Calculate confusion matrix and other metrics
cm = confusion_matrix(y_test, y_pred_class)
accuracy = accuracy_score(y_test, y_pred_class)
precision = precision_score(y_test, y_pred_class)
recall = recall_score(y_test, y_pred_class)
f1 = f1_score(y_test, y_pred_class)

# Printing the evaluation metrics
print(f"\nConfusion Matrix:\n{cm}")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.7341 - loss: 0.5636 - val_accuracy: 0.5040 - val_loss: 43.8730 - learning_rate: 0.0010
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9212 - loss: 0.2462 - val_accuracy: 0.1630 - val_loss: 68.9281 - learning_rate: 0.0010
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9261 - loss: 0.1923 - val_accuracy: 0.5610 - val_loss: 23.4999 - learning_rate: 0.0010
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9355 - loss: 0.1697 - val_accuracy: 0.9030 - val_loss: 3.4822 - learning_rate: 0.0010
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9383 - loss: 0.1560 - val_accuracy: 0.5540 - val_loss: 40.3509 - learning_rate: 0.0010
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9514 - loss: 0.1252 - val_accuracy: 0.5030 - val_loss: 61.5727 - learning_rate: 0.0010
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9471 - loss: 0.1341 - val_accuracy: 0.6070 - val_loss: 15.0592 - learning_rate: 0.0010
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9481 - loss: 0.1320 - val_accuracy: 0.9010 - val_loss: 10.4177 - learning_rate: 0.0010
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9508 - loss: 0.1265 - val_accuracy: 0.9010 - val_loss: 9.0502 - learning_rate: 0.0010
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9577 - loss: 0.1085 - val_accuracy: 0.6150 - val_loss: 13.5112 - learning_rate: 2.0000e-04
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9637 - loss: 0.1052 - val_accuracy: 0.9000 - val_loss: 6.6007 - learning_rate: 2.0000e-04
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9584 - loss: 0.1097 - val_accuracy: 0.9010 - val_loss: 6.1567 - learning_rate: 2.0000e-04
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9581 - loss: 0.1205 - val_accuracy: 0.7720 - val_loss: 7.5086 - learning_rate: 2.0000e-04
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9599 - loss: 0.1167 - val_accuracy: 0.9020 - val_loss: 6.9948 - learning_rate: 2.0000e-04
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
#
# Confusion Matrix:
# [[900   1]
#  [ 96   3]]
# Accuracy: 0.903
# Precision: 0.75
# Recall: 0.030303030303030304
# F1 Score: 0.05825242718446602

# %%
# Plotting the training history
history_dict = history.history

# Extract accuracy and loss for training and validation sets
train_acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']

# Plotting accuracy
plt.figure(figsize=(10, 6))
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plotting loss
plt.figure(figsize=(10, 6))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # How prediction can be made using trained TabNet model

# %%
import joblib
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from pytorch_tabnet.tab_model import TabNetClassifier

# Load the frequency encoding for 'ZIP Code'
zip_code_freq = joblib.load('zip_code_freq_encoder.pkl')

# Load the label encoders
label_encoders = joblib.load('label_encoders.pkl')

tb_cls = TabNetClassifier()
tb_cls.load_model('best_model.zip')

new_data = {
    'Age': [25],
    'Experience': [1],
    'Income': [690],
    'ZIP Code': ['175101'],
    'Family': [4],
    'CCAvg': [12.60],
    'Education': ['1'],
    'Mortgage': [50],
    'Securities Account': [False],
    'CD Account': [True],
    'Online': [True],
    'CreditCard': [False]
}

# Convert new_data to DataFrame
new_data = pd.DataFrame(new_data)

# Display the structure of new_data
print("New DataFrame:")
print(new_data.info())

# Apply the same frequency encoding to 'ZIP Code'
new_data['ZIP Code'] = new_data['ZIP Code'].map(zip_code_freq)

# Apply the same label encoding to other columns
columns_to_encode = ['Education', 'CD Account', 'Online', 'CreditCard', 'Securities Account']
for col in columns_to_encode:
    le = label_encoders[col]
    new_data[col] = le.transform(new_data[col])

# Convert the DataFrame to numpy array if necessary
new_data_np = new_data.to_numpy()

# Make predictions using the loaded model
predictions = tb_cls.predict(new_data_np)

# If you need probabilities instead of class labels
probabilities = tb_cls.predict_proba(new_data_np)

print("Predictions:")
print(predictions)

print("Probabilities:")
print(probabilities)
# Out:
# New DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 1 non-null      int64
#  1   Experience          1 non-null      int64
#  2   Income              1 non-null      int64
#  3   ZIP Code            1 non-null      object
#  4   Family              1 non-null      int64
#  5   CCAvg               1 non-null      float64
#  6   Education           1 non-null      object
#  7   Mortgage            1 non-null      int64
#  8   Securities Account  1 non-null      bool
#  9   CD Account          1 non-null      bool
#  10  Online              1 non-null      bool
#  11  CreditCard          1 non-null      bool
# dtypes: bool(4), float64(1), int64(5), object(2)
# memory usage: 196.0+ bytes
# None
# Predictions:
# [0]
# Probabilities:
# [[0.814614   0.18538606]]
